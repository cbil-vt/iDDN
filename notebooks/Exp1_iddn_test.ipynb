# %% [markdown]
# # iDDN test

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from iddn import iddn, tools_export, visualize2
from iddn import tools, simulation, performance

# %load_ext autoreload
# %autoreload 2

# %%
n_node = 10
gg = simulation.ThreeLayerGraph(n_node=n_node)
dep_mat = gg.get_dependency_matrix()
dat1, dat2 = gg.draw_sample(n1=500, n2=500)
# Out:
# 0.1000000000000001
# 0.0999999999999998

# %%
plt.imshow(gg.adj_mat1)

# %%
rho1_mat = gg.get_rho_matrix(rho_a=0.15, rho_b=0.15)
rho2_mat = gg.get_rho_matrix(rho_a=0.01, rho_b=0.01)
g_rec = iddn.iddn(dat1, dat2, lambda1=rho1_mat, lambda2=rho2_mat, mthd='resi', dep_mat=dep_mat)

# %%
g_est = np.abs(g_rec[0])>1e-5
plt.imshow(g_est.T)
